# %%
class Product:
  def __init__(self):
      self.name = "reo"
      self.age = "7"

  def printinfo(self):
    print(self.name)
    print(self.age)

human = Product()
human.printinfo()
# Out:
# reo
# 7
